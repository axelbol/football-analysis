# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

from pywaffle import Waffle

# %%
df_possession = pd.read_html('https://fbref.com/en/matches/87c96d20/Washington-Spirit-Gotham-FC-November-16-2024-NWSL', attrs={'id':'stats_e442aad0_possession'})[0]

# %%
df_possession
# Out:
#     Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                 Player                  #             Nation
# 0         Ashley Hatch               33.0             us USA
# 1    Rosemonde Kouassi               19.0             ci CIV
# 2   Brittany Ratcliffe               13.0             us USA
# 3       Trinity Rodman                2.0             us USA
# 4         Leicy Santos               10.0             co COL
# 5          Lena Silano                4.0             us USA
# 6   Heather Stainbrook               22.0                NaN
# 7       Makenna Morris                8.0             us USA
# 8        Hal Hershfelt               17.0             us USA
# 9        Casey Krueger                3.0             us USA
# 10         Esme Morgan               24.0            eng ENG
# 11         Anaïg Butel                5.0             fr FRA
# 12        Tara McKeown                9.0             us USA
# 13       Paige Metayer               26.0             us USA
# 14     Gabrielle Carle               14.0             ca CAN
# 15    Aubrey Kingsbury                1.0             us USA
# 16          16 Players                NaN                NaN
#
#    Unnamed: 3_level_0 Unnamed: 4_level_0 Unnamed: 5_level_0 Touches          \
#                   Pos                Age                Min Touches Def Pen
# 0                  FW             29-175                120      45       0
# 1                  LW             22-326                 88      37       0
# 2                  LW             30-283                 32      13       0
# 3                  RW             22-180                120      53       0
# 4                  AM             28-184                 78      43       1
# 5                  AM             24-293                 42      19       0
# 6                  DM                NaN                 66      31       3
# 7                  DM             22-204                 54      25       0
# 8                  DM             22-044                120      78       2
# 9                  LB             34-085                120      73       0
# 10                 CB             24-029                104      58      12
# 11                 CB             32-275                 16      10       1
# 12                 CB             25-137                120      65       7
# 13                 RB             24-054                 78      54       1
# 14                 RB             26-035                 42      50       1
# 15                 GK             32-362                120      44      33
# 16                NaN                NaN               1320     698      61
#
#                     ... Carries                                       \
#    Def 3rd Mid 3rd  ... Carries TotDist PrgDist PrgC 1/3 CPA Mis Dis
# 0        2      18  ...      21      95      39    1   1   0   5   7
# 1        8      14  ...      28     351     202    8   5   7   2   3
# 2        1       2  ...       7      36      10    0   0   0   2   0
# 3        8      17  ...      32     276     120    5   2   1   7   2
# 4       10      16  ...      26     154      86    4   1   0   3   3
# 5        2       9  ...       9      40       8    0   1   0   0   0
# 6       11      11  ...       6      15       7    0   0   0   1   0
# 7        3      10  ...       7      53      49    2   0   1   0   0
# 8       26      42  ...      30     121      38    0   0   0   2   0
# 9       31      26  ...      28     110      67    2   0   0   1   1
# 10      41      16  ...      17      32       7    0   0   0   1   0
# 11       7       3  ...       6      11       4    0   0   0   0   0
# 12      29      34  ...      35     209     132    3   1   0   1   0
# 13      20      21  ...      11      81      65    4   1   0   2   0
# 14      12      18  ...      13      77      46    1   0   0   1   0
# 15      41       3  ...      20      98      48    0   0   0   0   0
# 16     252     260  ...     296    1759     928   30  12   9  28  16
#
#    Receiving
#          Rec PrgR
# 0         27    5
# 1         25    5
# 2          9    2
# 3         35   12
# 4         33    5
# 5         16    4
# 6          8    1
# 7         12    1
# 8         51    1
# 9         32    1
# 10        29    0
# 11         8    0
# 12        41    2
# 13        21    1
# 14        16    4
# 15        16    0
# 16       379   44
#
# [17 rows x 28 columns]

# %%
df_possession.columns
# Out:
# MultiIndex([('Unnamed: 0_level_0',  'Player'),
#             ('Unnamed: 1_level_0',       '#'),
#             ('Unnamed: 2_level_0',  'Nation'),
#             ('Unnamed: 3_level_0',     'Pos'),
#             ('Unnamed: 4_level_0',     'Age'),
#             ('Unnamed: 5_level_0',     'Min'),
#             (           'Touches', 'Touches'),
#             (           'Touches', 'Def Pen'),
#             (           'Touches', 'Def 3rd'),
#             (           'Touches', 'Mid 3rd'),
#             (           'Touches', 'Att 3rd'),
#             (           'Touches', 'Att Pen'),
#             (           'Touches',    'Live'),
#             (          'Take-Ons',     'Att'),
#             (          'Take-Ons',    'Succ'),
#             (          'Take-Ons',   'Succ%'),
#             (          'Take-Ons',    'Tkld'),
#             (          'Take-Ons',   'Tkld%'),
#             (           'Carries', 'Carries'),
#             (           'Carries', 'TotDist'),
#             (           'Carries', 'PrgDist'),
#             (           'Carries',    'PrgC'),
#             (           'Carries',     '1/3'),
#             (           'Carries',     'CPA'),
#             (           'Carries',     'Mis'),
#             (           'Carries',     'Dis'),
#             (         'Receiving',     'Rec'),
#             (         'Receiving',    'PrgR')],
#            )

# %%
df_possession.columns.values
# Out:
# array([('Unnamed: 0_level_0', 'Player'), ('Unnamed: 1_level_0', '#'),
#        ('Unnamed: 2_level_0', 'Nation'), ('Unnamed: 3_level_0', 'Pos'),
#        ('Unnamed: 4_level_0', 'Age'), ('Unnamed: 5_level_0', 'Min'),
#        ('Touches', 'Touches'), ('Touches', 'Def Pen'),
#        ('Touches', 'Def 3rd'), ('Touches', 'Mid 3rd'),
#        ('Touches', 'Att 3rd'), ('Touches', 'Att Pen'),
#        ('Touches', 'Live'), ('Take-Ons', 'Att'), ('Take-Ons', 'Succ'),
#        ('Take-Ons', 'Succ%'), ('Take-Ons', 'Tkld'), ('Take-Ons', 'Tkld%'),
#        ('Carries', 'Carries'), ('Carries', 'TotDist'),
#        ('Carries', 'PrgDist'), ('Carries', 'PrgC'), ('Carries', '1/3'),
#        ('Carries', 'CPA'), ('Carries', 'Mis'), ('Carries', 'Dis'),
#        ('Receiving', 'Rec'), ('Receiving', 'PrgR')], dtype=object)

# %% [markdown]
# Join columns

# %%
df_possession.columns = ['_'.join(col).strip() for col in df_posession.columns.values]

# %%
df_possession.columns
# Out:
# Index(['Unnamed: 0_level_0_Player', 'Unnamed: 1_level_0_#',
#        'Unnamed: 2_level_0_Nation', 'Unnamed: 3_level_0_Pos',
#        'Unnamed: 4_level_0_Age', 'Unnamed: 5_level_0_Min', 'Touches_Touches',
#        'Touches_Def Pen', 'Touches_Def 3rd', 'Touches_Mid 3rd',
#        'Touches_Att 3rd', 'Touches_Att Pen', 'Touches_Live', 'Take-Ons_Att',
#        'Take-Ons_Succ', 'Take-Ons_Succ%', 'Take-Ons_Tkld', 'Take-Ons_Tkld%',
#        'Carries_Carries', 'Carries_TotDist', 'Carries_PrgDist', 'Carries_PrgC',
#        'Carries_1/3', 'Carries_CPA', 'Carries_Mis', 'Carries_Dis',
#        'Receiving_Rec', 'Receiving_PrgR'],
#       dtype='object')

# %%
df_possession
# Out:
#    Unnamed: 0_level_0_Player  Unnamed: 1_level_0_# Unnamed: 2_level_0_Nation  \
# 0               Ashley Hatch                  33.0                    us USA
# 1          Rosemonde Kouassi                  19.0                    ci CIV
# 2         Brittany Ratcliffe                  13.0                    us USA
# 3             Trinity Rodman                   2.0                    us USA
# 4               Leicy Santos                  10.0                    co COL
# 5                Lena Silano                   4.0                    us USA
# 6         Heather Stainbrook                  22.0                       NaN
# 7             Makenna Morris                   8.0                    us USA
# 8              Hal Hershfelt                  17.0                    us USA
# 9              Casey Krueger                   3.0                    us USA
# 10               Esme Morgan                  24.0                   eng ENG
# 11               Anaïg Butel                   5.0                    fr FRA
# 12              Tara McKeown                   9.0                    us USA
# 13             Paige Metayer                  26.0                    us USA
# 14           Gabrielle Carle                  14.0                    ca CAN
# 15          Aubrey Kingsbury                   1.0                    us USA
# 16                16 Players                   NaN                       NaN
#
#    Unnamed: 3_level_0_Pos Unnamed: 4_level_0_Age  Unnamed: 5_level_0_Min  \
# 0                      FW                 29-175                     120
# 1                      LW                 22-326                      88
# 2                      LW                 30-283                      32
# 3                      RW                 22-180                     120
# 4                      AM                 28-184                      78
# 5                      AM                 24-293                      42
# 6                      DM                    NaN                      66
# 7                      DM                 22-204                      54
# 8                      DM                 22-044                     120
# 9                      LB                 34-085                     120
# 10                     CB                 24-029                     104
# 11                     CB                 32-275                      16
# 12                     CB                 25-137                     120
# 13                     RB                 24-054                      78
# 14                     RB                 26-035                      42
# 15                     GK                 32-362                     120
# 16                    NaN                    NaN                    1320
#
#     Touches_Touches  Touches_Def Pen  Touches_Def 3rd  Touches_Mid 3rd  ...  \
# 0                45                0                2               18  ...
# 1                37                0                8               14  ...
# 2                13                0                1                2  ...
# 3                53                0                8               17  ...
# 4                43                1               10               16  ...
# 5                19                0                2                9  ...
# 6                31                3               11               11  ...
# 7                25                0                3               10  ...
# 8                78                2               26               42  ...
# 9                73                0               31               26  ...
# 10               58               12               41               16  ...
# 11               10                1                7                3  ...
# 12               65                7               29               34  ...
# 13               54                1               20               21  ...
# 14               50                1               12               18  ...
# 15               44               33               41                3  ...
# 16              698               61              252              260  ...
#
#     Carries_Carries  Carries_TotDist  Carries_PrgDist  Carries_PrgC  \
# 0                21               95               39             1
# 1                28              351              202             8
# 2                 7               36               10             0
# 3                32              276              120             5
# 4                26              154               86             4
# 5                 9               40                8             0
# 6                 6               15                7             0
# 7                 7               53               49             2
# 8                30              121               38             0
# 9                28              110               67             2
# 10               17               32                7             0
# 11                6               11                4             0
# 12               35              209              132             3
# 13               11               81               65             4
# 14               13               77               46             1
# 15               20               98               48             0
# 16              296             1759              928            30
#
#     Carries_1/3  Carries_CPA  Carries_Mis  Carries_Dis  Receiving_Rec  \
# 0             1            0            5            7             27
# 1             5            7            2            3             25
# 2             0            0            2            0              9
# 3             2            1            7            2             35
# 4             1            0            3            3             33
# 5             1            0            0            0             16
# 6             0            0            1            0              8
# 7             0            1            0            0             12
# 8             0            0            2            0             51
# 9             0            0            1            1             32
# 10            0            0            1            0             29
# 11            0            0            0            0              8
# 12            1            0            1            0             41
# 13            1            0            2            0             21
# 14            0            0            1            0             16
# 15            0            0            0            0             16
# 16           12            9           28           16            379
#
#     Receiving_PrgR
# 0                5
# 1                5
# 2                2
# 3               12
# 4                5
# 5                4
# 6                1
# 7                1
# 8                1
# 9                1
# 10               0
# 11               0
# 12               2
# 13               1
# 14               4
# 15               0
# 16              44
#
# [17 rows x 28 columns]

# %%
df_possession.to_csv('/home/axel/Code/Python/axel/football_analysis/csv/spirit_possession.csv', index=False)

# %% [markdown]
# Read CSV

# %%
df = pd.read_csv('/home/axel/Code/Python/axel/football_analysis/csv/spirit_possession.csv')
df.head()
# Out:
#   Unnamed: 0_level_0_Player  Unnamed: 1_level_0_# Unnamed: 2_level_0_Nation  \
# 0              Ashley Hatch                  33.0                    us USA
# 1         Rosemonde Kouassi                  19.0                    ci CIV
# 2        Brittany Ratcliffe                  13.0                    us USA
# 3            Trinity Rodman                   2.0                    us USA
# 4              Leicy Santos                  10.0                    co COL
#
#   Unnamed: 3_level_0_Pos Unnamed: 4_level_0_Age  Unnamed: 5_level_0_Min  \
# 0                     FW                 29-175                     120
# 1                     LW                 22-326                      88
# 2                     LW                 30-283                      32
# 3                     RW                 22-180                     120
# 4                     AM                 28-184                      78
#
#    Touches_Touches  Touches_Def Pen  Touches_Def 3rd  Touches_Mid 3rd  ...  \
# 0               45                0                2               18  ...
# 1               37                0                8               14  ...
# 2               13                0                1                2  ...
# 3               53                0                8               17  ...
# 4               43                1               10               16  ...
#
#    Carries_Carries  Carries_TotDist  Carries_PrgDist  Carries_PrgC  \
# 0               21               95               39             1
# 1               28              351              202             8
# 2                7               36               10             0
# 3               32              276              120             5
# 4               26              154               86             4
#
#    Carries_1/3  Carries_CPA  Carries_Mis  Carries_Dis  Receiving_Rec  \
# 0            1            0            5            7             27
# 1            5            7            2            3             25
# 2            0            0            2            0              9
# 3            2            1            7            2             35
# 4            1            0            3            3             33
#
#    Receiving_PrgR
# 0               5
# 1               5
# 2               2
# 3              12
# 4               5
#
# [5 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0_level_0_Player', 'Unnamed: 1_level_0_#',
#        'Unnamed: 2_level_0_Nation', 'Unnamed: 3_level_0_Pos',
#        'Unnamed: 4_level_0_Age', 'Unnamed: 5_level_0_Min', 'Touches_Touches',
#        'Touches_Def Pen', 'Touches_Def 3rd', 'Touches_Mid 3rd',
#        'Touches_Att 3rd', 'Touches_Att Pen', 'Touches_Live', 'Take-Ons_Att',
#        'Take-Ons_Succ', 'Take-Ons_Succ%', 'Take-Ons_Tkld', 'Take-Ons_Tkld%',
#        'Carries_Carries', 'Carries_TotDist', 'Carries_PrgDist', 'Carries_PrgC',
#        'Carries_1/3', 'Carries_CPA', 'Carries_Mis', 'Carries_Dis',
#        'Receiving_Rec', 'Receiving_PrgR'],
#       dtype='object')

# %%
# delete columns reassigning to the DF

df_possession_clean = df.drop(['Unnamed: 1_level_0_#', 'Unnamed: 2_level_0_Nation', 'Unnamed: 3_level_0_Pos', 'Unnamed: 4_level_0_Age', 'Unnamed: 5_level_0_Min', 'Touches_Live', 'Take-Ons_Att', 'Take-Ons_Succ', 'Take-Ons_Succ%', 'Take-Ons_Tkld', 'Take-Ons_Tkld%', 'Carries_Carries', 'Carries_TotDist', 'Carries_PrgDist', 'Carries_PrgC', 'Carries_1/3', 'Carries_CPA', 'Carries_Mis', 'Carries_Dis', 'Receiving_Rec', 'Receiving_PrgR'], axis=1)

# %%
# delete columns without reassigning to the DF

df.drop(['Unnamed: 1_level_0_#', 'Unnamed: 2_level_0_Nation', 'Unnamed: 3_level_0_Pos', 'Unnamed: 4_level_0_Age', 'Unnamed: 5_level_0_Min', 'Touches_Live', 'Take-Ons_Att', 'Take-Ons_Succ', 'Take-Ons_Succ%', 'Take-Ons_Tkld', 'Take-Ons_Tkld%', 'Carries_Carries', 'Carries_TotDist', 'Carries_PrgDist', 'Carries_PrgC', 'Carries_1/3', 'Carries_CPA', 'Carries_Mis', 'Carries_Dis', 'Receiving_Rec', 'Receiving_PrgR'], axis=1, inplace=True)

# %%
df_possession_clean
# Out:
#    Unnamed: 0_level_0_Player  Touches_Touches  Touches_Def Pen  \
# 0               Ashley Hatch               45                0
# 1          Rosemonde Kouassi               37                0
# 2         Brittany Ratcliffe               13                0
# 3             Trinity Rodman               53                0
# 4               Leicy Santos               43                1
# 5                Lena Silano               19                0
# 6         Heather Stainbrook               31                3
# 7             Makenna Morris               25                0
# 8              Hal Hershfelt               78                2
# 9              Casey Krueger               73                0
# 10               Esme Morgan               58               12
# 11               Anaïg Butel               10                1
# 12              Tara McKeown               65                7
# 13             Paige Metayer               54                1
# 14           Gabrielle Carle               50                1
# 15          Aubrey Kingsbury               44               33
# 16                16 Players              698               61
#
#     Touches_Def 3rd  Touches_Mid 3rd  Touches_Att 3rd  Touches_Att Pen
# 0                 2               18               26               10
# 1                 8               14               20               10
# 2                 1                2               10                4
# 3                 8               17               28                3
# 4                10               16               18                4
# 5                 2                9                8                1
# 6                11               11                9                1
# 7                 3               10               12                2
# 8                26               42               13                2
# 9                31               26               17                5
# 10               41               16                1                0
# 11                7                3                0                0
# 12               29               34                4                1
# 13               20               21               14                2
# 14               12               18               21                3
# 15               41                3                0                0
# 16              252              260              201               48

# %%
# rename column labels

df_possession_clean.rename(columns={'Unnamed: 0_level_0_Player': 'Player', 'Touches_Touches': 'Touches', 'Touches_Def Pen': 'DefPen', 'Touches_Def 3rd': 'Def3rd', 'Touches_Mid 3rd': 'Mid_3rd', 'Touches_Att 3rd': 'Att_3rd', 'Touches_Att Pen': 'AttPen'}, inplace=True)
df_possession_clean
# Out:
#                 Player  Touches  DefPen  Def3rd  Mid_3rd  Att_3rd  AttPen
# 0         Ashley Hatch       45       0       2       18       26      10
# 1    Rosemonde Kouassi       37       0       8       14       20      10
# 2   Brittany Ratcliffe       13       0       1        2       10       4
# 3       Trinity Rodman       53       0       8       17       28       3
# 4         Leicy Santos       43       1      10       16       18       4
# 5          Lena Silano       19       0       2        9        8       1
# 6   Heather Stainbrook       31       3      11       11        9       1
# 7       Makenna Morris       25       0       3       10       12       2
# 8        Hal Hershfelt       78       2      26       42       13       2
# 9        Casey Krueger       73       0      31       26       17       5
# 10         Esme Morgan       58      12      41       16        1       0
# 11         Anaïg Butel       10       1       7        3        0       0
# 12        Tara McKeown       65       7      29       34        4       1
# 13       Paige Metayer       54       1      20       21       14       2
# 14     Gabrielle Carle       50       1      12       18       21       3
# 15    Aubrey Kingsbury       44      33      41        3        0       0
# 16          16 Players      698      61     252      260      201      48

# %%
# sort data by touches

df_possession_clean = df_possession_clean.sort_values(by=['Touches'], ascending=False)
df_possession_clean
# Out:
#                 Player  Touches  DefPen  Def3rd  Mid_3rd  Att_3rd  AttPen
# 16          16 Players      698      61     252      260      201      48
# 8        Hal Hershfelt       78       2      26       42       13       2
# 9        Casey Krueger       73       0      31       26       17       5
# 12        Tara McKeown       65       7      29       34        4       1
# 10         Esme Morgan       58      12      41       16        1       0
# 13       Paige Metayer       54       1      20       21       14       2
# 3       Trinity Rodman       53       0       8       17       28       3
# 14     Gabrielle Carle       50       1      12       18       21       3
# 0         Ashley Hatch       45       0       2       18       26      10
# 15    Aubrey Kingsbury       44      33      41        3        0       0
# 4         Leicy Santos       43       1      10       16       18       4
# 1    Rosemonde Kouassi       37       0       8       14       20      10
# 6   Heather Stainbrook       31       3      11       11        9       1
# 7       Makenna Morris       25       0       3       10       12       2
# 5          Lena Silano       19       0       2        9        8       1
# 2   Brittany Ratcliffe       13       0       1        2       10       4
# 11         Anaïg Butel       10       1       7        3        0       0

# %%
# delete row with player's count

df_possession_clean.drop(16, inplace=True)
df_possession_clean
# Out:
#                 Player  Touches  DefPen  Def3rd  Mid_3rd  Att_3rd  AttPen
# 8        Hal Hershfelt       78       2      26       42       13       2
# 9        Casey Krueger       73       0      31       26       17       5
# 12        Tara McKeown       65       7      29       34        4       1
# 10         Esme Morgan       58      12      41       16        1       0
# 13       Paige Metayer       54       1      20       21       14       2
# 3       Trinity Rodman       53       0       8       17       28       3
# 14     Gabrielle Carle       50       1      12       18       21       3
# 0         Ashley Hatch       45       0       2       18       26      10
# 15    Aubrey Kingsbury       44      33      41        3        0       0
# 4         Leicy Santos       43       1      10       16       18       4
# 1    Rosemonde Kouassi       37       0       8       14       20      10
# 6   Heather Stainbrook       31       3      11       11        9       1
# 7       Makenna Morris       25       0       3       10       12       2
# 5          Lena Silano       19       0       2        9        8       1
# 2   Brittany Ratcliffe       13       0       1        2       10       4
# 11         Anaïg Butel       10       1       7        3        0       0

# %%
# delete touches column

df_possession_clean = df_possession_clean.drop('Touches', axis=1)
df_possession_clean
# Out:
#                 Player  DefPen  Def3rd  Mid_3rd  Att_3rd  AttPen
# 8        Hal Hershfelt       2      26       42       13       2
# 9        Casey Krueger       0      31       26       17       5
# 12        Tara McKeown       7      29       34        4       1
# 10         Esme Morgan      12      41       16        1       0
# 13       Paige Metayer       1      20       21       14       2
# 3       Trinity Rodman       0       8       17       28       3
# 14     Gabrielle Carle       1      12       18       21       3
# 0         Ashley Hatch       0       2       18       26      10
# 15    Aubrey Kingsbury      33      41        3        0       0
# 4         Leicy Santos       1      10       16       18       4
# 1    Rosemonde Kouassi       0       8       14       20      10
# 6   Heather Stainbrook       3      11       11        9       1
# 7       Makenna Morris       0       3       10       12       2
# 5          Lena Silano       0       2        9        8       1
# 2   Brittany Ratcliffe       0       1        2       10       4
# 11         Anaïg Butel       1       7        3        0       0

# %%
# transpose the DF

df_possession_clean = df_possession_clean.T
df_possession_clean
# Out:
#                     8              9             12           10  \
# Player   Hal Hershfelt  Casey Krueger  Tara McKeown  Esme Morgan
# DefPen               2              0             7           12
# Def3rd              26             31            29           41
# Mid_3rd             42             26            34           16
# Att_3rd             13             17             4            1
# AttPen               2              5             1            0
#
#                     13              3                14            0   \
# Player   Paige Metayer  Trinity Rodman  Gabrielle Carle  Ashley Hatch
# DefPen               1               0                1             0
# Def3rd              20               8               12             2
# Mid_3rd             21              17               18            18
# Att_3rd             14              28               21            26
# AttPen               2               3                3            10
#
#                        15            4                  1   \
# Player   Aubrey Kingsbury  Leicy Santos  Rosemonde Kouassi
# DefPen                 33             1                  0
# Def3rd                 41            10                  8
# Mid_3rd                 3            16                 14
# Att_3rd                 0            18                 20
# AttPen                  0             4                 10
#
#                          6               7            5                   2   \
# Player   Heather Stainbrook  Makenna Morris  Lena Silano  Brittany Ratcliffe
# DefPen                    3               0            0                   0
# Def3rd                   11               3            2                   1
# Mid_3rd                  11              10            9                   2
# Att_3rd                   9              12            8                  10
# AttPen                    1               2            1                   4
#
#                   11
# Player   Anaïg Butel
# DefPen             1
# Def3rd             7
# Mid_3rd            3
# Att_3rd            0
# AttPen             0

# %%
# move column names

df_possession_clean.columns = df_possession_clean.iloc[0]
df_possession_clean
# Out:
# Player   Hal Hershfelt  Casey Krueger  Tara McKeown  Esme Morgan  \
# Player   Hal Hershfelt  Casey Krueger  Tara McKeown  Esme Morgan
# DefPen               2              0             7           12
# Def3rd              26             31            29           41
# Mid_3rd             42             26            34           16
# Att_3rd             13             17             4            1
# AttPen               2              5             1            0
#
# Player   Paige Metayer  Trinity Rodman  Gabrielle Carle  Ashley Hatch  \
# Player   Paige Metayer  Trinity Rodman  Gabrielle Carle  Ashley Hatch
# DefPen               1               0                1             0
# Def3rd              20               8               12             2
# Mid_3rd             21              17               18            18
# Att_3rd             14              28               21            26
# AttPen               2               3                3            10
#
# Player   Aubrey Kingsbury  Leicy Santos  Rosemonde Kouassi  \
# Player   Aubrey Kingsbury  Leicy Santos  Rosemonde Kouassi
# DefPen                 33             1                  0
# Def3rd                 41            10                  8
# Mid_3rd                 3            16                 14
# Att_3rd                 0            18                 20
# AttPen                  0             4                 10
#
# Player   Heather Stainbrook  Makenna Morris  Lena Silano  Brittany Ratcliffe  \
# Player   Heather Stainbrook  Makenna Morris  Lena Silano  Brittany Ratcliffe
# DefPen                    3               0            0                   0
# Def3rd                   11               3            2                   1
# Mid_3rd                  11              10            9                   2
# Att_3rd                   9              12            8                  10
# AttPen                    1               2            1                   4
#
# Player   Anaïg Butel
# Player   Anaïg Butel
# DefPen             1
# Def3rd             7
# Mid_3rd            3
# Att_3rd            0
# AttPen             0

# %%
# drop player row

df_possession_clean = df_possession_clean.drop('Player')
df_possession_clean
# Out:
# Player  Hal Hershfelt Casey Krueger Tara McKeown Esme Morgan Paige Metayer  \
# DefPen              2             0            7          12             1
# Def3rd             26            31           29          41            20
# Mid_3rd            42            26           34          16            21
# Att_3rd            13            17            4           1            14
# AttPen              2             5            1           0             2
#
# Player  Trinity Rodman Gabrielle Carle Ashley Hatch Aubrey Kingsbury  \
# DefPen               0               1            0               33
# Def3rd               8              12            2               41
# Mid_3rd             17              18           18                3
# Att_3rd             28              21           26                0
# AttPen               3               3           10                0
#
# Player  Leicy Santos Rosemonde Kouassi Heather Stainbrook Makenna Morris  \
# DefPen             1                 0                  3              0
# Def3rd            10                 8                 11              3
# Mid_3rd           16                14                 11             10
# Att_3rd           18                20                  9             12
# AttPen             4                10                  1              2
#
# Player  Lena Silano Brittany Ratcliffe Anaïg Butel
# DefPen            0                  0           1
# Def3rd            2                  1           7
# Mid_3rd           9                  2           3
# Att_3rd           8                 10           0
# AttPen            1                  4           0

# %%
players_list = df_possession_clean.columns.values.tolist()
players_list
# Out:
# ['Hal Hershfelt',
#  'Casey Krueger',
#  'Tara McKeown',
#  'Esme Morgan',
#  'Paige Metayer',
#  'Trinity Rodman',
#  'Gabrielle Carle',
#  'Ashley Hatch',
#  'Aubrey Kingsbury',
#  'Leicy Santos',
#  'Rosemonde Kouassi',
#  'Heather Stainbrook',
#  'Makenna Morris',
#  'Lena Silano',
#  'Brittany Ratcliffe',
#  'Anaïg Butel']

# %%
# remove player

df_possession_clean = pd.DataFrame(df_possession_clean, columns=players_list)
df_possession_clean
# Out:
#         Hal Hershfelt Casey Krueger Tara McKeown Esme Morgan Paige Metayer  \
# DefPen              2             0            7          12             1
# Def3rd             26            31           29          41            20
# Mid_3rd            42            26           34          16            21
# Att_3rd            13            17            4           1            14
# AttPen              2             5            1           0             2
#
#         Trinity Rodman Gabrielle Carle Ashley Hatch Aubrey Kingsbury  \
# DefPen               0               1            0               33
# Def3rd               8              12            2               41
# Mid_3rd             17              18           18                3
# Att_3rd             28              21           26                0
# AttPen               3               3           10                0
#
#         Leicy Santos Rosemonde Kouassi Heather Stainbrook Makenna Morris  \
# DefPen             1                 0                  3              0
# Def3rd            10                 8                 11              3
# Mid_3rd           16                14                 11             10
# Att_3rd           18                20                  9             12
# AttPen             4                10                  1              2
#
#         Lena Silano Brittany Ratcliffe Anaïg Butel
# DefPen            0                  0           1
# Def3rd            2                  1           7
# Mid_3rd           9                  2           3
# Att_3rd           8                 10           0
# AttPen            1                  4           0

# %%
# df_possession_clean['Hal Hershfelt'].dtype
df_possession_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, DefPen to AttPen
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Hal Hershfelt       5 non-null      object
#  1   Casey Krueger       5 non-null      object
#  2   Tara McKeown        5 non-null      object
#  3   Esme Morgan         5 non-null      object
#  4   Paige Metayer       5 non-null      object
#  5   Trinity Rodman      5 non-null      object
#  6   Gabrielle Carle     5 non-null      object
#  7   Ashley Hatch        5 non-null      object
#  8   Aubrey Kingsbury    5 non-null      object
#  9   Leicy Santos        5 non-null      object
#  10  Rosemonde Kouassi   5 non-null      object
#  11  Heather Stainbrook  5 non-null      object
#  12  Makenna Morris      5 non-null      object
#  13  Lena Silano         5 non-null      object
#  14  Brittany Ratcliffe  5 non-null      object
#  15  Anaïg Butel         5 non-null      object
# dtypes: object(16)
# memory usage: 680.0+ bytes

# %%
# List the columns you want to convert to int

df_possession_clean['Hal Hershfelt'] = df_possession_clean['Hal Hershfelt'].astype(int)

# %%
# convert all DF to int

df_possession_clean = df_possession_clean.astype(int)

# %% [markdown]
# Waffle Plot

# %%
values = df_possession_clean.iloc[:, 0]

# Normalize values to percentages if they don't sum to 100
values = (values / values.sum()) * 100

# Create a Waffle chart
fig = plt.figure(
    FigureClass=Waffle,
    rows=10,  # Number of rows in the waffle grid
    values=values,
    # labels=list(df_possession_clean.index),
    labels=[f"Category {i+1} ({v:.1f}%)" for i, v in enumerate(values)],
    figsize=(10, 5),
    # characters='⚡',
    font_size=24,
    icon_style='solid',
    icon_legend=True,
    icons=['sun', 'cloud-showers-heavy', 'snowflake', 'cloud-showers-heavy', 'snowflake'],
    legend={
        # 'loc': 'upper left',
        # 'labels': ['Sun', 'Shower', 'Snow', 'Shower', 'Snow'],
        'loc': 'upper left',
        'bbox_to_anchor': (1, 1),
        # 'ncol': len(values),
        # 'framealpha': 0,
        'fontsize': 12
        },
    title={
        'label': players_list[0],
        'loc': 'center',
        'fontdict': {
            'fontsize': 20
        }
    }
)

# plt.savefig('/home/axel/Code/images/image.png', dpi=fig.dpi, bbox_inches='tight', pad_inches=0.35)
# Out:
# <Waffle size 1000x500 with 1 Axes>

# %% [markdown]
# Get labels with percentage

# %%
# Normalize values to percentages if they don't sum to 100
values = (values / values.sum()) * 100

# Create labels with both names and percentages
labels = [f"{name} ({value:.1f}%)" for name, value in zip(df_possession_clean.index, values)]

# Create a Waffle chart
fig = plt.figure(
    FigureClass=Waffle,
    rows=10,  # Number of rows in the waffle grid
    values=values,
    labels=labels,  # Use the combined labels
    figsize=(10, 5),
    font_size=24,
    icon_style='solid',
    icon_legend=True,
    icons=['sun', 'cloud-showers-heavy', 'snowflake', 'cloud-showers-heavy', 'snowflake'],
    legend={
        'loc': 'upper left',
        'bbox_to_anchor': (1, 1),
        'fontsize': 12
    },
    title={
        'label': players_list[0],
        'loc': 'center',
        'fontdict': {
            'fontsize': 20
        }
    }
)

# Save or display the figure
# plt.savefig('/home/axel/Code/images/image.png', dpi=fig.dpi, bbox_inches='tight', pad_inches=0.35)
plt.show()
# Out:
# <Waffle size 1000x500 with 1 Axes>

# %%
from highlight_text import fig_text

# %%
fig = plt.figure(
    FigureClass=Waffle,
    rows=10,
    figsize=(10,10),
    tight=False,
    # labels=list(df_possession_clean.index),
    plots={
        331:{ #3x3 - 1 is the first plot
            'values':df_possession_clean.iloc[:,0],
            # 'labels': [f"{k} ({v})" for k, v in data['Factory C'].items()],
            'title':{
                'label':players_list[0],
                # 'labels': [f"{k} ({v})" for k, v in data['Factory C'].items()],
                'color':'white',
                'loc':'left',
                'fontsize': 15
            }
        },
        332:{ #3x3 - 2 is the first plot
            'values':df_possession_clean.iloc[:,1],
            'title':{
                'label':players_list[1],
                'color':'white',
                'loc':'left',
                'fontsize': 15
            }
        },
        333:{ #3x3 - 3 is the first plot
            'values':df_possession_clean.iloc[:,2],
            'title':{
                'label':players_list[2],
                'color':'white',
                'loc':'left',
                'fontsize': 15
            }
        },
        334:{ #3x3 - 4 is the first plot
            'values':df_possession_clean.iloc[:,3],
            'title':{
                'label':players_list[3],
                'color':'white',
                'loc':'left',
                'fontsize': 15
            }
        },
        335:{ #3x3 - 5 is the first plot
            'values':df_possession_clean.iloc[:,4],
            'title':{
                'label':players_list[4],
                'color':'white',
                'loc':'left',
                'fontsize': 15
            }
        },
        336:{ #3x3 - 6 is the first plot
            'values':df_possession_clean.iloc[:,5],
            'title':{
                'label':players_list[5],
                'color':'white',
                'loc':'left',
                'fontsize': 15
            }
        },
        337:{ #3x3 - 7 is the first plot
            'values':df_possession_clean.iloc[:,6],
            'title':{
                'label':players_list[6],
                'color':'white',
                'loc':'left',
                'fontsize': 15
            }
        },
        338:{ #3x3 - 8 is the first plot
            'values':df_possession_clean.iloc[:,7],
            'title':{
                'label':players_list[7],
                'color':'white',
                'loc':'left',
                'fontsize': 15
            }
        },
        339:{ #3x3 - 9 is the first plot
            'values':df_possession_clean.iloc[:,8],
            'title':{
                'label':players_list[8],
                'color':'white',
                'loc':'left',
                'fontsize': 15
            }
        }
    },
    colors = ['#eae2b7', '#e76f51', '#f4a261', '#e9c461', '#2a9d8f']
)

bbox_pad = 1.5
bboxprops = {'linewidth': 0, 'pad': bbox_pad}

fig_text(
    s='This is the title \n <Def Pen>, <Def 3rd>, <Mid 3rd>, <Att 3rd>, + <Att Pen>',
    x=0.125, y=.99,
    fontsize=18,
    textalign='center',
    vsep=12,
    color='lightgrey',
    highlight_textprops=[
        {'color': 'black', 'weight': 'bold', 'bbox': {'facecolor':'#eae2b7', **bboxprops}},
        # {"color": '#eae2b7'},
        {"color": '#e76f51'},
        {"color": '#f4a261'},
        {"color": '#e9c461'},
        {"color": '#2a9d8f'}
    ]
    #  highlight_colors = ['#eae2b7', '#e76f51', '#f4a261', '#e9c461', '#2a9d8f']
)

fig_text(
    s='<*Aufgrund der deutlich höheren Zahl an Tests sind die Werte aus dem Frühjahr nur eingeschränkt mit>\n' '<denen aus dem Herbst vergleichbar>\n\n' 'Quelle: <Johns Hopkins CSSE>, Stand 14.10.2020, eigene Berechnung Plotdesign: <DER SPIEGEL>',
    highlight_textprops=[
        {'color': 'k', 'weight': 'regular'},
        {'color': 'k', 'weight': 'regular'},
        {'color': 'k', 'weight': 'bold'},
        {'color': '#fc5203', 'weight': 'bold'}
    ],
    color='#969696',
    x=0, y=0.1,
    fontsize=13
)

fig.patch.set_facecolor('#313332')
# Out:
# <Waffle size 1000x1000 with 9 Axes>

# %% [markdown]
# Not working well

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pywaffle import Waffle

# Define subplots
plots = {
    311: {'values': df_possession_clean['Hal Hershfelt'], 'labels': [f"{k} ({v})" for k, v in df_possession_clean['Hal Hershfelt'].items()],  # Chart A
          'legend': {'loc': 'upper left', 'bbox_to_anchor': (1.05, 1), 'fontsize': 8},
          'title': {'label': 'Chart A', 'loc': 'left', 'fontsize': 12}},
    312: {'values': df_possession_clean['Casey Krueger'], 'labels': [f"{k} ({v})" for k, v in df_possession_clean['Casey Krueger'].items()],  # Chart B
          'legend': {'loc': 'upper left', 'bbox_to_anchor': (1.2, 1), 'fontsize': 8},
          'title': {'label': 'Chart B', 'loc': 'left', 'fontsize': 12}},
      313: {'values': df_possession_clean['Tara McKeown'], 'labels': [f"{k} ({v})" for k, v in df_possession_clean['Tara McKeown'].items()],  # Chart B
          'legend': {'loc': 'upper left', 'bbox_to_anchor': (1.2, 1), 'fontsize': 8},
          'title': {'label': 'Chart B', 'loc': 'left', 'fontsize': 12}},

}

# Create figure with multiple subplots
fig = plt.figure(FigureClass=Waffle, plots=plots, rows=10, cmap_name="tab20b")

# Customize figure
fig.suptitle('Title for all plots', fontsize=12, fontweight='bold')

# Show the plot
plt.show()
# Out:
# <Waffle size 640x480 with 3 Axes>

# %%
import pandas as pd

fig = plt.figure(
    FigureClass=Waffle,
    plots={
        311: {
            'values': df_possession_clean['Hal Hershfelt'],
            'labels': ["{0} ({1})".format(n, v) for n, v in df_possession_clean['Hal Hershfelt'].items()],
            'legend': {'loc': 'upper left', 'bbox_to_anchor': (1.05, 1), 'fontsize': 8},
            'title': {'label': '2016 Virginia Presidential Election Results', 'loc': 'left'}
        },
        312: {
            'values': df_possession_clean['Casey Krueger'] / 30000,
            'labels': ["{0} ({1})".format(n, v) for n, v in df_possession_clean['Casey Krueger'].items()],
            'legend': {'loc': 'upper left', 'bbox_to_anchor': (1.2, 1), 'fontsize': 8},
            'title': {'label': '2016 Maryland Presidential Election Results', 'loc': 'left'}
        },
        313: {
            'values': df_possession_clean['Tara McKeown'] / 30000,
            'labels': ["{0} ({1})".format(n, v) for n, v in df_possession_clean['Tara McKeown'].items()],
            'legend': {'loc': 'upper left', 'bbox_to_anchor': (1.3, 1), 'fontsize': 8},
            'title': {'label': '2016 West Virginia Presidential Election Results', 'loc': 'left'}
        },
    },
    rows=5,
    colors=("#2196f3", "#ff5252", "#999999", "#999999", "#999999"),  # Default argument values for subplots
    figsize=(9, 5)  # figsize is a parameter of plt.figure
)
# Out:
# <Waffle size 900x500 with 3 Axes>

# %%
fig = plt.figure(
    FigureClass=Waffle,
    rows=10,
    figsize=(10,10),
    tight=False,
    plots={
        331:{ #3x3 - 1 is the first plot
            'values': df_possession_clean['Hal Hershfelt'],
            'labels': [f"{k} ({v})" for k, v in df_possession_clean['Hal Hershfelt'].items()],
            'title':{
                'label':players_list[0],
                # 'labels': [f"{k} ({v})" for k, v in data['Factory C'].items()],
                'color':'white',
                'loc':'left',
                'fontsize': 15
            }
        },
        332:{ #3x3 - 1 is the first plot
            'values': df_possession_clean['Casey Krueger'],
            'labels': [f"{k} ({v})" for k, v in df_possession_clean['Casey Krueger'].items()],
            'legend': {'loc': 'center', 'bbox_to_anchor': (1.2, 1), 'fontsize': 8},
            'title':{
                'label':players_list[1],
                # 'labels': [f"{k} ({v})" for k, v in data['Factory C'].items()],
                'color':'white',
                'loc':'center',
                'fontsize': 15
            }
        },
        333: {
            'values': df_possession_clean['Tara McKeown'],
            'labels': [f"{k} ({v})" for k, v in df_possession_clean['Tara McKeown'].items()],  # Chart B
          'legend': {'loc': 'upper left', 'bbox_to_anchor': (1.2, 1), 'fontsize': 8},
          'title': {'label': players_list[2], 'loc': 'left', 'fontsize': 12}},
    },
    colors = ['#eae2b7', '#e76f51', '#f4a261', '#e9c461', '#2a9d8f']
)

bbox_pad = 1.5
bboxprops = {'linewidth': 0, 'pad': bbox_pad}

fig_text(
    s='This is the title \n <Def Pen>, <Def 3rd>, <Mid 3rd>, <Att 3rd>, + <Att Pen>',
    x=0.125, y=.99,
    fontsize=18,
    textalign='center',
    vsep=12,
    color='lightgrey',
    highlight_textprops=[
        {'color': 'black', 'weight': 'bold', 'bbox': {'facecolor':'#eae2b7', **bboxprops}},
        # {"color": '#eae2b7'},
        {"color": '#e76f51'},
        {"color": '#f4a261'},
        {"color": '#e9c461'},
        {"color": '#2a9d8f'}
    ]
    #  highlight_colors = ['#eae2b7', '#e76f51', '#f4a261', '#e9c461', '#2a9d8f']
)

fig_text(
    s='<*Aufgrund der deutlich höheren Zahl an Tests sind die Werte aus dem Frühjahr nur eingeschränkt mit>\n' '<denen aus dem Herbst vergleichbar>\n\n' 'Quelle: <Johns Hopkins CSSE>, Stand 14.10.2020, eigene Berechnung Plotdesign: <DER SPIEGEL>',
    highlight_textprops=[
        {'color': 'k', 'weight': 'regular'},
        {'color': 'k', 'weight': 'regular'},
        {'color': 'k', 'weight': 'bold'},
        {'color': '#fc5203', 'weight': 'bold'}
    ],
    color='#969696',
    x=0, y=0.1,
    fontsize=13
)

fig.patch.set_facecolor('#313332')
# Out:
# <Waffle size 1000x1000 with 3 Axes>

# %%
fig = plt.figure(
    FigureClass=Waffle,
    rows=10,
    figsize=(10, 10),
    tight=False,
    plots={
        311: {
            'values': (df_possession_clean.iloc[:, 0] / df_possession_clean.iloc[:, 0].sum()) * 100,
            'labels': [f"{name} ({value:.1f}%)" for name, value in zip(df_possession_clean.index, (df_possession_clean.iloc[:, 0] / df_possession_clean.iloc[:, 0].sum()) * 100)],
            'legend': {'loc': 'upper left', 'bbox_to_anchor': (1.2, 1), 'fontsize': 8},
            'title': {
                'label': players_list[0],
                'color': 'white',
                'loc': 'left',
                'fontsize': 15
            }
        },
        312: {
            'values': (df_possession_clean.iloc[:, 1] / df_possession_clean.iloc[:, 1].sum()) * 100,
            'labels': [f"{name} ({value:.1f}%)" for name, value in zip(df_possession_clean.index, (df_possession_clean.iloc[:, 1] / df_possession_clean.iloc[:, 1].sum()) * 100)],
            'legend': {'loc': 'upper left', 'bbox_to_anchor': (1.2, 1), 'fontsize': 8},
            'title': {
                'label': players_list[1],
                'color': 'white',
                'loc': 'left',
                'fontsize': 15
            }
        },
        313: {
            'values': (df_possession_clean.iloc[:, 2] / df_possession_clean.iloc[:, 2].sum()) * 100,
            'labels': [f"{name} ({value:.1f}%)" for name, value in zip(df_possession_clean.index, (df_possession_clean.iloc[:, 2] / df_possession_clean.iloc[:, 2].sum()) * 100)],
            'legend': {'loc': 'center', 'bbox_to_anchor': (1.2, 1), 'fontsize': 8},
            'title': {
                'label': players_list[2],
                'color': 'white',
                'loc': 'left',
                'fontsize': 15
            }
        },
        # Repeat for other plots...
    },
    colors=['#eae2b7', '#e76f51', '#f4a261', '#e9c461', '#2a9d8f']
)

bbox_pad = 1.5
bboxprops = {'linewidth': 0, 'pad': bbox_pad}
fig.patch.set_facecolor('#313332')
plt.show()
# Out:
# <Waffle size 1000x1000 with 3 Axes>
